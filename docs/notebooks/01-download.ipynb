# %% [markdown]
# [![lamindata](https://img.shields.io/badge/laminlabs/rxrx-mediumseagreen)](https://lamin.ai/laminlabs/rxrx/record/core/Transform?id=VxfLdk7rOTnbz8)

# %% [markdown]
# # Download metadata & embeddings of RxRx1

# %% [markdown]
# This notebook downloads metadata and embedding files of [RxRx1](https://www.rxrx.ai/rxrx1).

# %% [markdown]
# ## Setup

# %%
# !lamin load falexwolf/rxrx
# Out:
# 💡 loading db URL from local cache
# 💡 loaded instance: falexwolf/rxrx

# %%
import lamindb as ln
# Out:
# 💡 loaded instance: falexwolf/rxrx (lamindb 0.59.4)

# %%
ln.track()
# Out:
# 💡 notebook imports: lamindb==0.59.0
# 💡 Transform(uid='VxfLdk7rOTnbz8', name='Download metadata & embeddings of RxRx1', short_name='01-download', version='0', type='notebook', updated_at=2023-11-05 16:02:29 UTC, created_by_id=1)
# 💡 Run(uid='DbYCOVDA8vkdNqYnsMcN', run_at=2023-11-05 16:02:29 UTC, transform_id=2, created_by_id=1)

# %% [markdown]
# ## Register the metadata files

# %% [markdown]
# The `metadata.csv` is downloaded from: https://www.rxrx.ai/rxrx1#Download

# %%
meta_file_rxrx1 = ln.File(
    "s3://lamindata/rxrx1/metadata.csv",
    description=(
        "Experimental design of RxRx1, e.g. what cell type and"
        " treatment are in each well."
    ),
)
meta_file_rxrx1.save()
# Out:
# ❗ returning existing file with same hash: File(uid='lt5RtX57c0LqMmZdhxZe', key='rxrx1/metadata.csv', suffix='.csv', description='Experimental design of RxRx1, e.g. what cell type and treatment are in each well.', size=10094584, hash='Qt-NZucDv7uEFX9HlP5pdw', hash_type='md5', visibility=0, key_is_virtual=False, updated_at=2023-11-05 16:01:31 UTC, storage_id=1, transform_id=2, run_id=1, created_by_id=1)

# %%
meta_file_rxrx1.view_flow()

# %% [markdown]
# ## Register the embedding files

# %% [markdown]
# The `embeddings.csv` is downloaded from: https://www.rxrx.ai/rxrx1#Download

# %%
embedding_file_rxrx1 = ln.File(
    "s3://lamindata/rxrx1/embeddings.csv",
    description=(
        "A large CSV file containing all of the deep learning embeddings for each"
        " image of RxRx1."
    ),
)
embedding_file_rxrx1.save()
# Out:
# ❗ returning existing file with same hash: File(uid='yLBYCR4x8lqG3LWKHZlh', key='rxrx1/embeddings.csv', suffix='.csv', description='A large CSV file containing all of the deep learning embeddings for each image of RxRx1.', size=172102542, hash='hVCamx0caBqCoybXkH1NCg-11', hash_type='md5-n', visibility=0, key_is_virtual=False, updated_at=2023-11-05 16:01:33 UTC, storage_id=1, transform_id=2, run_id=1, created_by_id=1)

# %%
embedding_file_rxrx1.view_flow()

# %%
# !lamin save 01-download.ipynb
# Out:
# ✅ Cell numbers increase consecutively: Awesome!
# 💡 loaded instance: falexwolf/rxrx (lamindb 0.59.4)
# ... uploading 01-download_stripped.ipynb: 1.00
# ... uploading 01-download.html: 1.00
# ✅ saved notebook and wrote source file and html report
# Transform(uid='VxfLdk7rOTnbz8', name='Download metadata & embeddings of RxRx1', short_name='01-download', version='0', type='notebook', updated_at=2023-11-05 16:03:19 UTC, latest_report_id=4, source_file_id=3, created_by_id=1)
# transform.source_file: File(uid='dF0sFraRFRmIChNQKYvZ', suffix='.ipynb', description='Source of transform VxfLdk7rOTnbz8', version='0', size=3564, hash='yK-aZL2djwRpRNB7_57dwQ', hash_type='md5', visibility=1, key_is_virtual=True, updated_at=2023-11-05 16:03:17 UTC, storage_id=1, created_by_id=1)
# transform.latest_report: File(uid='rINadfNr3cME5ChXqQSU', suffix='.html', description='Report of transform VxfLdk7rOTnbz8', size=293259, hash='yXoBqEszbAxh2kyXyEetlQ', hash_type='md5', visibility=1, key_is_virtual=True, updated_at=2023-11-05 16:03:18 UTC, storage_id=1, created_by_id=1)
