# %% [markdown]
# [![lamindata](https://img.shields.io/badge/laminlabs/rxrx-mediumseagreen)](https://lamin.ai/laminlabs/rxrx/record/core/Transform?id=VxfLdk7rOTnbz8)

# %% [markdown]
# # Download metadata & embeddings of RxRx1

# %% [markdown]
# This notebook downloads metadata and embedding files of [RxRx1](https://www.rxrx.ai/rxrx1).

# %% [markdown]
# ## Setup

# %%
# !lamin init --storage test-recursion --schema bionty,lamin1
# Out:
# ✅ saved: User(uid='DzTjkKse', handle='testuser1', name='Test User1', updated_at=2023-12-13 05:29:52 UTC)
# ✅ saved: Storage(uid='m7Keesfc', root='/Users/falexwolf/repos/rxrx-lamin/docs/notebooks/test-recursion', type='local', updated_at=2023-12-13 05:29:52 UTC, created_by_id=1)
# 💡 loaded instance: testuser1/test-recursion
# 💡 did not register local instance on hub

# %%
import lamindb as ln
# Out:
# 💡 lamindb instance: testuser1/test-recursion

# %%
ln.track()
# Out:
# 💡 notebook imports: lamindb==0.63.3
# 💡 saved: Transform(uid='VxfLdk7rOTnbz8', name='Download metadata & embeddings of RxRx1', short_name='01-download', version='0', type=notebook, updated_at=2023-12-13 05:29:57 UTC, created_by_id=1)
# 💡 saved: Run(uid='HYGISiiWHbUB98ZrcfdF', run_at=2023-12-13 05:29:57 UTC, transform_id=1, created_by_id=1)

# %% [markdown]
# ## Register the metadata

# %% [markdown]
# The `metadata.csv` is downloaded from: https://www.rxrx.ai/rxrx1#Download

# %%
meta_rxrx1 = ln.Artifact(
    "s3://lamindata/rxrx1/metadata.csv",
    description=(
        "Experimental design of RxRx1, e.g. what cell type and"
        " treatment are in each well."
    ),
)
meta_rxrx1.save()

# %%
meta_rxrx1.view_flow()

# %% [markdown]
# ## Register the embedding files

# %% [markdown]
# The `embeddings.csv` is downloaded from: https://www.rxrx.ai/rxrx1#Download

# %%
embeddings_rxrx1 = ln.Artifact(
    "s3://lamindata/rxrx1/embeddings.csv",
    description=(
        "A large CSV file containing all of the deep learning embeddings for each"
        " image of RxRx1."
    ),
)
embeddings_rxrx1.save()

# %%
embeddings_rxrx1.view_flow()
